# %% [markdown]
# # Week1: Pandas Introduction, DataFrame from CSV
#
# The best intro guide, but it's big, is 10 Minutes to Pandas: http://pandas.pydata.org/pandas-docs/stable/10min.html
#
# Let's start to work with pandas, to make analysis of this data easier.  Our convention is to import as "pd":

# %%
import pandas as pd

# numpy is a library very useful in Python for numerical stuff
import numpy as np

# two librairies for plotting
import matplotlib.pyplot as plt
import seaborn 
# %matplotlib inline

# %% [markdown]
# ## 1. Reading/Writing files<a name="1. Reading/Writing files"></a>
# ### 1.1. Reading<a name="1.1 Reading"></a>

# %% [markdown]
# In this notebook we are going to use two different datasets : one with more 'qualitative' information and one with 'quantitative' info

# %%
# Pandas has built-in tools to read files, including csv and excel.
complaints = pd.read_csv('data/311-service-requests.csv')
bikes = pd.read_csv('data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True)
# Out:
# C:\Users\Hugo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Depending on your pandas version, you might see an error like "DtypeWarning: Columns (8) have mixed types". This means that it's encountered a problem reading in our data. In this case it almost certainly means that it has columns where some of the entries are strings and some are NaN which are recognized as float by the funciton.
#
# For now we're going to ignore it and hope we don't run into a problem, but in the long run we'd need to investigate this warning.

# %%
#complaints
bikes
# Out:
#           Date  Berri 1  Brébeuf (données non disponibles)  \
# 0   2012-01-01       35                                NaN
# 1   2012-01-02       83                                NaN
# 2   2012-01-03      135                                NaN
# 3   2012-01-04      144                                NaN
# 4   2012-01-05      197                                NaN
# 5   2012-01-06      146                                NaN
# 6   2012-01-07       98                                NaN
# 7   2012-01-08       95                                NaN
# 8   2012-01-09      244                                NaN
# 9   2012-01-10      397                                NaN
# 10  2012-01-11      273                                NaN
# 11  2012-01-12      157                                NaN
# 12  2012-01-13       75                                NaN
# 13  2012-01-14       32                                NaN
# 14  2012-01-15       54                                NaN
# 15  2012-01-16      168                                NaN
# 16  2012-01-17      155                                NaN
# 17  2012-01-18      139                                NaN
# 18  2012-01-19      191                                NaN
# 19  2012-01-20      161                                NaN
# 20  2012-01-21       53                                NaN
# 21  2012-01-22       71                                NaN
# 22  2012-01-23      210                                NaN
# 23  2012-01-24      299                                NaN
# 24  2012-01-25      334                                NaN
# 25  2012-01-26      306                                NaN
# 26  2012-01-27       91                                NaN
# 27  2012-01-28       80                                NaN
# 28  2012-01-29       87                                NaN
# 29  2012-01-30      219                                NaN
# ..         ...      ...                                ...
# 280 2012-10-07     1580                                NaN
# 281 2012-10-08     1854                                NaN
# 282 2012-10-09     4787                                NaN
# 283 2012-10-10     3115                                NaN
# 284 2012-10-11     3746                                NaN
# 285 2012-10-12     3169                                NaN
# 286 2012-10-13     1783                                NaN
# 287 2012-10-14      587                                NaN
# 288 2012-10-15     3292                                NaN
# 289 2012-10-16     3739                                NaN
# 290 2012-10-17     4098                                NaN
# 291 2012-10-18     4671                                NaN
# 292 2012-10-19     1313                                NaN
# 293 2012-10-20     2011                                NaN
# 294 2012-10-21     1277                                NaN
# 295 2012-10-22     3650                                NaN
# 296 2012-10-23     4177                                NaN
# 297 2012-10-24     3744                                NaN
# 298 2012-10-25     3735                                NaN
# 299 2012-10-26     4290                                NaN
# 300 2012-10-27     1857                                NaN
# 301 2012-10-28     1310                                NaN
# 302 2012-10-29     2919                                NaN
# 303 2012-10-30     2887                                NaN
# 304 2012-10-31     2634                                NaN
# 305 2012-11-01     2405                                NaN
# 306 2012-11-02     1582                                NaN
# 307 2012-11-03      844                                NaN
# 308 2012-11-04      966                                NaN
# 309 2012-11-05     2247                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 0                        0             38             51       26
# 1                        1             68            153       53
# 2                        2            104            248       89
# 3                        1            116            318      111
# 4                        2            124            330       97
# 5                        0             98            244       86
# 6                        2             80            108       53
# 7                        1             62             98       64
# 8                        2            165            432      198
# 9                        3            238            563      275
# 10                       0            182            443      258
# 11                       1            134            261      137
# 12                       0             41            105       64
# 13                       0             54             56       19
# 14                       0             33             60       18
# 15                       2            136            312      137
# 16                       0             86            256       74
# 17                       0             66            188       68
# 18                       1            104            248       79
# 19                       4             96            217       67
# 20                       0             47             70       32
# 21                       0             41             73       35
# 22                       6            114            357       91
# 23                       1            189            444      174
# 24                       1            217            453      180
# 25                       0            215            495      191
# 26                       5             79            204       65
# 27                       1             61            123       33
# 28                       1             65            132       40
# 29                       0            146            371      152
# ..                     ...            ...            ...      ...
# 280                    660            922           1629      860
# 281                    880            987           1818     1040
# 282                   2210           3026           5138     3418
# 283                   1537           2081           3681     2608
# 284                   1857           2569           4694     3034
# 285                   1460           2261           4045     2564
# 286                    802           1205           2113     1183
# 287                    287            443            852      503
# 288                   1678           2165           4197     2754
# 289                   1858           2684           4681     2997
# 290                   1964           2645           4836     3063
# 291                   2292           3129           5542     3477
# 292                    597            885           1668     1209
# 293                    748           1323           2266     1213
# 294                    609            869           1777      898
# 295                   1819           2495           4800     3023
# 296                   1997           2795           5216     3233
# 297                   1868           2625           4900     3035
# 298                   1815           2528           5010     3017
# 299                   1987           2754           5246     3000
# 300                    792           1244           2461     1193
# 301                    697            910           1776      955
# 302                   1458           2071           3768     2440
# 303                   1251           2007           3516     2255
# 304                   1294           1835           3453     2220
# 305                   1208           1701           3082     2076
# 306                    737           1109           2277     1392
# 307                    380            612           1137      713
# 308                    446            710           1277      692
# 309                   1170           1705           3221     2143
#
#      Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 0              10       16                                  NaN
# 1               6       43                                  NaN
# 2               3       58                                  NaN
# 3               8       61                                  NaN
# 4              13       95                                  NaN
# 5               4       75                                  NaN
# 6               6       54                                  NaN
# 7              11       63                                  NaN
# 8              12      173                                  NaN
# 9              18      241                                  NaN
# 10             12      194                                  NaN
# 11              9       63                                  NaN
# 12              2        0                                  NaN
# 13              0        1                                  NaN
# 14              0        0                                  NaN
# 15              1        0                                  NaN
# 16              0        0                                  NaN
# 17              3        0                                  NaN
# 18              3        0                                  NaN
# 19              1        1                                  NaN
# 20              1        0                                  NaN
# 21              5        0                                  NaN
# 22              6        0                                  NaN
# 23              4        0                                  NaN
# 24              4        0                                  NaN
# 25              0        1                                  NaN
# 26              0        0                                  NaN
# 27              9        1                                  NaN
# 28              7        0                                  NaN
# 29              2        0                                  NaN
# ..            ...      ...                                  ...
# 280           695     2052                                  NaN
# 281          1115     2502                                  NaN
# 282           927     4078                                  NaN
# 283           560     2703                                  NaN
# 284           558     3457                                  NaN
# 285           448     3224                                  NaN
# 286           681     2309                                  NaN
# 287            65      952                                  NaN
# 288           560     3183                                  NaN
# 289           554     3593                                  NaN
# 290           728     3834                                  NaN
# 291          1108     4245                                  NaN
# 292           111     1486                                  NaN
# 293           797     2243                                  NaN
# 294           242     1648                                  NaN
# 295           757     3721                                  NaN
# 296           795     3554                                  NaN
# 297           649     3622                                  NaN
# 298           631     3767                                  NaN
# 299          1456     4578                                  NaN
# 300           618     2471                                  NaN
# 301           387     1876                                  NaN
# 302           411     2795                                  NaN
# 303           338     2790                                  NaN
# 304           245     2570                                  NaN
# 305           165     2461                                  NaN
# 306            97     1888                                  NaN
# 307           105     1302                                  NaN
# 308           197     1374                                  NaN
# 309           179     2430                                  NaN
#
# [310 rows x 10 columns]

# %%
# type of the results
type(complaints)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ** The function returns a DataFrame which is an object with a lot of things defined on it **
#
# ### 1.2. Writing<a name="1.2 Writing"></a>
#
# *We can also save out a csv file from pandas in a simple way*

# %%
complaints.to_csv("data/saved_complaints.csv")

# %% [markdown]
# *What if we only wanted some of the columns? We can pick which ones to write out*

# %%
complaints.to_csv("data/saved_complaints2.csv", columns=["Created Date", "Closed Date"])

# %% [markdown]
# *If you don't want the extra index row with the rownumber and no header, you can prevent that from being saved by saying "index=None" and "header = None)*

# %%
complaints.to_csv("data/saved_complaints3.csv", columns=["Created Date", "Closed Date"], index=None, header=None)

# %% [markdown]
# ## 2.Viewing Data<a name="2. Viewing Data"></a>
# ### 2.1. See the top & bottom rows of the frame<a name="2.1. See the top & bottom rows of the frame"></a>

# %%
complaints.head(3)  # this command shows us the result of the operation, with the top 5 rows of the table
#bikes.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department          Illegal Parking
# 2  New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
#
#    Incident Address                    ...                     \
# 0  90-03 169 STREET                    ...
# 1         58 AVENUE                    ...
# 2     4060 BROADWAY                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
#
# [3 rows x 52 columns]

# %%
complaints.tail(3)
#bikes.tail()

# %% [markdown]
# ### 2.2. Plotting data

# %%
bikes.head()

# %%
# To make a plot from pandas, we use the dataframe object we created, then tell the plot function
# what to use as the X column and what to use as the Y column.
bikes.plot( 'Date',"Maisonneuve 1",figsize=(10,5))

# %% [markdown]
# ## 3. Selection
# *Let's use complaints again*
# ### 3.1. Get a slice from a DataFrame
# #### Get a column

# %%
# comment/uncomment lines
#complaints["Agency"]
#complaints.Agency
#complaints.loc[:,'Agency'] #selection by label
complaints.iloc[:,3]     #selection by position
# Out:
# 0          NYPD
# 1          NYPD
# 2          NYPD
# 3          NYPD
# 4         DOHMH
# 5          NYPD
# 6          NYPD
# 7          NYPD
# 8          NYPD
# 9          NYPD
# 10         NYPD
# 11         NYPD
# 12         NYPD
# 13         NYPD
# 14        DOHMH
# 15         NYPD
# 16         NYPD
# 17         NYPD
# 18          DOT
# 19         NYPD
# 20         NYPD
# 21         NYPD
# 22         NYPD
# 23         NYPD
# 24         NYPD
# 25         NYPD
# 26          DOT
# 27        DOHMH
# 28         NYPD
# 29          DOT
#           ...
# 111039     NYPD
# 111040     NYPD
# 111041      DEP
# 111042     NYPD
# 111043     NYPD
# 111044     NYPD
# 111045      DEP
# 111046      DEP
# 111047     NYPD
# 111048     NYPD
# 111049     NYPD
# 111050      DEP
# 111051     NYPD
# 111052      DEP
# 111053     DSNY
# 111054     NYPD
# 111055     NYPD
# 111056      DOT
# 111057      DEP
# 111058     NYPD
# 111059     NYPD
# 111060      DEP
# 111061     NYPD
# 111062      DEP
# 111063      DEP
# 111064      DPR
# 111065     NYPD
# 111066     NYPD
# 111067     NYPD
# 111068     NYPD
# Name: Agency, Length: 111069, dtype: object

# %% [markdown]
# #### get a line

# %%
bikes.head()
# Out:
#         Date  Berri 1  Brébeuf (données non disponibles)  \
# 0 2012-01-01       35                                NaN
# 1 2012-01-02       83                                NaN
# 2 2012-01-03      135                                NaN
# 3 2012-01-04      144                                NaN
# 4 2012-01-05      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)
# 0       16                                  NaN
# 1       43                                  NaN
# 2       58                                  NaN
# 3       61                                  NaN
# 4       95                                  NaN

# %%
# comment/uncomment lines
complaints.iloc[1,:]
#complaints.loc[1,:] #Selection by Label
# Out:
# Unique Key                                                        26593698
# Created Date                                        10/31/2013 02:01:04 AM
# Closed Date                                                            NaN
# Agency                                                                NYPD
# Agency Name                                New York City Police Department
# Complaint Type                                             Illegal Parking
# Descriptor                                    Commercial Overnight Parking
# Location Type                                              Street/Sidewalk
# Incident Zip                                                         11378
# Incident Address                                                 58 AVENUE
# Street Name                                                      58 AVENUE
# Cross Street 1                                                    58 PLACE
# Cross Street 2                                                   59 STREET
# Intersection Street 1                                                  NaN
# Intersection Street 2                                                  NaN
# Address Type                                                     BLOCKFACE
# City                                                               MASPETH
# Landmark                                                               NaN
# Facility Type                                                     Precinct
# Status                                                                Open
# Due Date                                            10/31/2013 10:01:04 AM
# Resolution Action Updated Date                                         NaN
# Community Board                                                  05 QUEENS
# Borough                                                             QUEENS
# X Coordinate (State Plane)                                     1.00935e+06
# Y Coordinate (State Plane)                                          201984
# Park Facility Name                                             Unspecified
# Park Borough                                                        QUEENS
# School Name                                                    Unspecified
# School Number                                                  Unspecified
# School Region                                                  Unspecified
# School Code                                                    Unspecified
# School Phone Number                                            Unspecified
# School Address                                                 Unspecified
# School City                                                    Unspecified
# School State                                                   Unspecified
# School Zip                                                     Unspecified
# School Not Found                                                         N
# School or Citywide Complaint                                           NaN
# Vehicle Type                                                           NaN
# Taxi Company Borough                                                   NaN
# Taxi Pick Up Location                                                  NaN
# Bridge Highway Name                                                    NaN
# Bridge Highway Direction                                               NaN
# Road Ramp                                                              NaN
# Bridge Highway Segment                                                 NaN
# Garage Lot Name                                                        NaN
# Ferry Direction                                                        NaN
# Ferry Terminal Name                                                    NaN
# Latitude                                                            40.721
# Longitude                                                         -73.9095
# Location                          (40.721040535628305, -73.90945306791765)
# Name: 1, dtype: object

# %%
print(type(complaints["Agency"]))
print(type(complaints.iloc[1,:]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ** A Slice of shape (1,) or (,1) is not a DataFrame but a Serie. The associated functions are not exactly the same **

# %%
# Possible to build a DataFrame from a serie
pd.DataFrame(complaints["Agency"]).head()
# Out:
#   Agency
# 0   NYPD
# 1   NYPD
# 2   NYPD
# 3   NYPD
# 4  DOHMH

# %% [markdown]
# #### select multiple rows and columns

# %% [markdown]
# Sometimes you want to combine your selection to rows and columns.  You can do that with `.loc[]` and `.iloc[]`.
#
# `iloc[rows,colums]` is for use with **number selectors** for row and column, and `loc[rows,columns]` is for **label selectors** for row and column (if they exist).
#
# The documentation for this is [here](http://pandas.pydata.org/pandas-docs/stable/indexing.html).
#
# If you use these, you must put a row selector first, then a column selector:

# %%
#Selecting by integer is done with iloc:
# this selects the first 10 rows and the first 3 columns.
complaints.iloc[0:10, 0:3]
# Out:
#    Unique Key            Created Date             Closed Date
# 0    26589651  10/31/2013 02:08:41 AM                     NaN
# 1    26593698  10/31/2013 02:01:04 AM                     NaN
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM
# 4    26590930  10/31/2013 01:53:44 AM                     NaN
# 5    26592370  10/31/2013 01:46:52 AM                     NaN
# 6    26595682  10/31/2013 01:46:40 AM                     NaN
# 7    26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM
# 8    26590540  10/31/2013 01:44:14 AM  10/31/2013 02:28:04 AM
# 9    26594392  10/31/2013 01:34:41 AM  10/31/2013 02:23:51 AM

# %%
# select rows 0:5, but the columns between the named columns here:
# Note, this works with row numbers because there is no label for the rows aside from numbers.
#  Notice this command loc is "inclusive" of the end points on the range.  Meaning it includes them.
complaints.loc[0:5, 'Closed Date':'Complaint Type']
# Out:
#               Closed Date Agency                              Agency Name  \
# 0                     NaN   NYPD          New York City Police Department
# 1                     NaN   NYPD          New York City Police Department
# 2  10/31/2013 02:40:32 AM   NYPD          New York City Police Department
# 3  10/31/2013 02:21:48 AM   NYPD          New York City Police Department
# 4                     NaN  DOHMH  Department of Health and Mental Hygiene
# 5                     NaN   NYPD          New York City Police Department
#
#             Complaint Type
# 0  Noise - Street/Sidewalk
# 1          Illegal Parking
# 2       Noise - Commercial
# 3          Noise - Vehicle
# 4                   Rodent
# 5       Noise - Commercial

# %% [markdown]
# What if we just want to know the complaint type and the borough, but not the rest of the information? Pandas makes it really easy to select a subset of the columns: just index with list of columns you want, using double square brackets (Or using the `loc[]` method above):

# %%
# Comment/uncomment

#complaints[['Complaint Type', 'Borough']]
complaints.loc[:,['Complaint Type', 'Borough']]
# Out:
#                   Complaint Type        Borough
# 0        Noise - Street/Sidewalk         QUEENS
# 1                Illegal Parking         QUEENS
# 2             Noise - Commercial      MANHATTAN
# 3                Noise - Vehicle      MANHATTAN
# 4                         Rodent      MANHATTAN
# 5             Noise - Commercial         QUEENS
# 6               Blocked Driveway         QUEENS
# 7             Noise - Commercial         QUEENS
# 8             Noise - Commercial      MANHATTAN
# 9             Noise - Commercial       BROOKLYN
# 10      Noise - House of Worship       BROOKLYN
# 11            Noise - Commercial      MANHATTAN
# 12               Illegal Parking      MANHATTAN
# 13               Noise - Vehicle          BRONX
# 14                        Rodent       BROOKLYN
# 15      Noise - House of Worship      MANHATTAN
# 16       Noise - Street/Sidewalk  STATEN ISLAND
# 17               Illegal Parking       BROOKLYN
# 18        Street Light Condition       BROOKLYN
# 19            Noise - Commercial      MANHATTAN
# 20      Noise - House of Worship       BROOKLYN
# 21            Noise - Commercial      MANHATTAN
# 22               Noise - Vehicle         QUEENS
# 23            Noise - Commercial       BROOKLYN
# 24              Blocked Driveway  STATEN ISLAND
# 25       Noise - Street/Sidewalk  STATEN ISLAND
# 26        Street Light Condition       BROOKLYN
# 27          Harboring Bees/Wasps      MANHATTAN
# 28       Noise - Street/Sidewalk      MANHATTAN
# 29        Street Light Condition  STATEN ISLAND
# ...                          ...            ...
# 111039        Noise - Commercial      MANHATTAN
# 111040        Noise - Commercial      MANHATTAN
# 111041                     Noise       BROOKLYN
# 111042   Noise - Street/Sidewalk      MANHATTAN
# 111043        Noise - Commercial       BROOKLYN
# 111044   Noise - Street/Sidewalk      MANHATTAN
# 111045              Water System      MANHATTAN
# 111046                     Noise       BROOKLYN
# 111047           Illegal Parking         QUEENS
# 111048   Noise - Street/Sidewalk      MANHATTAN
# 111049        Noise - Commercial       BROOKLYN
# 111050                     Noise      MANHATTAN
# 111051        Noise - Commercial      MANHATTAN
# 111052              Water System      MANHATTAN
# 111053         Derelict Vehicles         QUEENS
# 111054   Noise - Street/Sidewalk       BROOKLYN
# 111055        Noise - Commercial       BROOKLYN
# 111056     Street Sign - Missing         QUEENS
# 111057                     Noise      MANHATTAN
# 111058        Noise - Commercial       BROOKLYN
# 111059   Noise - Street/Sidewalk      MANHATTAN
# 111060                     Noise      MANHATTAN
# 111061        Noise - Commercial         QUEENS
# 111062              Water System      MANHATTAN
# 111063              Water System      MANHATTAN
# 111064   Maintenance or Facility       BROOKLYN
# 111065           Illegal Parking         QUEENS
# 111066   Noise - Street/Sidewalk      MANHATTAN
# 111067        Noise - Commercial       BROOKLYN
# 111068          Blocked Driveway       BROOKLYN
#
# [111069 rows x 2 columns]

# %% [markdown]
# ### 3.2. Boolean Indexing

# %%
complaints['Unique Key'] > 26595140
# Out:
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
# 5         False
# 6          True
# 7          True
# 8         False
# 9         False
# 10         True
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 111039    False
# 111040    False
# 111041    False
# 111042    False
# 111043    False
# 111044    False
# 111045    False
# 111046    False
# 111047    False
# 111048    False
# 111049    False
# 111050    False
# 111051    False
# 111052    False
# 111053    False
# 111054    False
# 111055    False
# 111056    False
# 111057    False
# 111058    False
# 111059    False
# 111060    False
# 111061    False
# 111062    False
# 111063    False
# 111064    False
# 111065    False
# 111066    False
# 111067    False
# 111068    False
# Name: Unique Key, Length: 111069, dtype: bool

# %%
complaints[complaints['Unique Key'] > 26595140].head()
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 3     26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 6     26595682  10/31/2013 01:46:40 AM                     NaN   NYPD
# 7     26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# 10    26595176  10/31/2013 01:25:12 AM                     NaN   NYPD
# 31    26595564  10/31/2013 12:30:36 AM                     NaN   NYPD
#
#                         Agency Name            Complaint Type  \
# 3   New York City Police Department           Noise - Vehicle
# 6   New York City Police Department          Blocked Driveway
# 7   New York City Police Department        Noise - Commercial
# 10  New York City Police Department  Noise - House of Worship
# 31  New York City Police Department   Noise - Street/Sidewalk
#
#           Descriptor        Location Type Incident Zip  \
# 3     Car/Truck Horn      Street/Sidewalk        10023
# 111059                     99 2 AVENUE
# 111066              344 EAST 28 STREET
#
#                           ...                    Bridge Highway Name  \
# 0                         ...                                    NaN
# 3                         ...                                    NaN
# 13                        ...                                    NaN
# 16                        ...                                    NaN
# 22                        ...                                    NaN
# 25                        ...                                    NaN
# 28                        ...                                    NaN
# 31                        ...                                    NaN
# 45                        ...                                    NaN
# 49                        ...                                    NaN
# 87                        ...                                    NaN
# 89                        ...                                    NaN
# 97                        ...                                    NaN
# 105                       ...                                    NaN
# 109                       ...                                    NaN
# 122                       ...                                    NaN
# 128                       ...                                    NaN
# 131                       ...                                    NaN
# 147                       ...                                    NaN
# 164                       ...                                    NaN
# 166                       ...                                    NaN
# 183                       ...                                    NaN
# 191                       ...                                    NaN
# 195                       ...                                    NaN
# 205                       ...                                    NaN
# 215                       ...                                    NaN
# 218                       ...                                    NaN
# 236                       ...                                    NaN
# 247                       ...                                    NaN
# 314                       ...                                    NaN
# ...                       ...                                    ...
# 110944                    ...                                    NaN
# 110946                    ...                                    NaN
# 110948                    ...                                    NaN
# 110954                    ...                                    NaN
# 110960                    ...                                    NaN
# 110962                    ...                                    NaN
# 110964                    ...                                    NaN
# 110972                    ...                                    NaN
# 110988                    ...                                    NaN
# 110990                    ...                                    NaN
# 110992                    ...                                    NaN
# 110996                    ...                                    NaN
# 111002                    ...                                    NaN
# 111004                    ...                                    NaN
# 111006                    ...                                    NaN
# 111009                    ...                                    NaN
# 111010                    ...                                    NaN
# 111011                    ...                                    NaN
# 111018                    ...                                    NaN
# 111021                    ...                                    NaN
# 111033                    ...                                    NaN
# 111034                    ...                                    NaN
# 111035                    ...                                    NaN
# 111037                    ...                                    NaN
# 111042                    ...                                    NaN
# 111044                    ...                                    NaN
# 111048                    ...                                    NaN
# 111054                    ...                                    NaN
# 111059                    ...                                    NaN
# 111066                    ...                                    NaN
#
#        Bridge Highway Direction Road Ramp Bridge Highway Segment  \
# 0                           NaN       NaN                    NaN
# 3                           NaN       NaN                    NaN
# 13                          NaN       NaN                    NaN
# 16                          NaN       NaN                    NaN
# 22                          NaN       NaN                    NaN
# 25                          NaN       NaN                    NaN
# 28                          NaN       NaN                    NaN
# 31                          NaN       NaN                    NaN
# 45                          NaN       NaN                    NaN
# 49                          NaN       NaN                    NaN
# 87                          NaN       NaN                    NaN
# 89                          NaN       NaN                    NaN
# 97                          NaN       NaN                    NaN
# 105                         NaN       NaN                    NaN
# 109                         NaN       NaN                    NaN
# 122                         NaN       NaN                    NaN
# 128                         NaN       NaN                    NaN
# 131                         NaN       NaN                    NaN
# 147                         NaN       NaN                    NaN
# 164                         NaN       NaN                    NaN
# 166                         NaN       NaN                    NaN
# 183                         NaN       NaN                    NaN
# 191                         NaN       NaN                    NaN
# 195                         NaN       NaN                    NaN
# 205                         NaN       NaN                    NaN
# 215                         NaN       NaN                    NaN
# 218                         NaN       NaN                    NaN
# 236                         NaN       NaN                    NaN
# 247                         NaN       NaN                    NaN
# 314                         NaN       NaN                    NaN
# ...                         ...       ...                    ...
# 110960 -73.964065   (40.63423411912724, -73.96406469568188)
# 110962 -73.937531   (40.80999157544199, -73.93753055422435)
# 110964 -73.959718   (40.81552658739026, -73.95971825500413)
# 110972 -73.765790   (40.70701250870174, -73.76579012401083)
# 110988 -73.901585   (40.82343209751158, -73.90158522761199)
# 110990 -73.980416   (40.72953107218499, -73.98041550317102)
# 110992 -73.785833   (40.594979009156205, -73.7858326072286)
# 110996 -73.880049   (40.870661854738415, -73.8800488518787)
# 111002 -73.964065   (40.63423411912724, -73.96406469568188)
# 111004 -73.911170   (40.75395970652276, -73.91116969635213)
# 111006 -73.964065   (40.63423411912724, -73.96406469568188)
# 111009 -73.929456     (40.8618290295582, -73.9294560541168)
# 111010 -73.946252   (40.81328414856855, -73.94625187216151)
# 111011 -73.915584  (40.836664485984976, -73.91558382507789)
# 111018 -73.739059  (40.673142046939304, -73.73905892129447)
# 111021 -73.963381   (40.70573258854396, -73.96338054284558)
# 111033 -73.940783   (40.81659709236496, -73.94078307354462)
# 111034 -73.941578   (40.83348848222364, -73.94157750579586)
# 111035 -73.955350  (40.692955608285715, -73.95534962720475)
# 111037 -74.006408      (40.73305407988208, -74.00640823601)
# 111042 -74.008299  (40.736303747410034, -74.00829935904578)
# 111044 -73.941018   (40.836532082987944, -73.9410182995914)
# 111048 -73.946328   (40.81333907832113, -73.94632769228208)
# 111054 -74.012207   (40.57751513866536, -74.01220705163807)
# 111059 -73.988660  (40.727251287038676, -73.98866028603422)
# 111066 -73.976952  (40.740295354643706, -73.97695165980414)
#
# [2678 rows x 52 columns]

# %% [markdown]
# **Using list of Booleans**

# %%
complaints['Complaint Type'] == 'Noise - Street/Sidewalk'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25         True
# 26        False
# 27        False
# 28         True
# 29        False
#           ...
# 111039    False
# 111040    False
# 111041    False
# 111042     True
# 111043    False
# 111044     True
# 111045    False
# 111046    False
# 111047    False
# 111048     True
# 111049    False
# 111050    False
# 111051    False
# 111052    False
# 111053    False
# 111054     True
# 111055    False
# 111056    False
# 111057    False
# 111058    False
# 111059     True
# 111060    False
# 111061    False
# 111062    False
# 111063    False
# 111064    False
# 111065    False
# 111066     True
# 111067    False
# 111068    False
# Name: Complaint Type, Length: 111069, dtype: bool

# %% [markdown]
# This is a big array of `True`s and `False`s, one for each row in our dataframe. When we index our dataframe with this array, we get just the rows where our boolean array evaluated to `True`.  It's important to note that for row filtering by a boolean array the length of our dataframe's index must be the same length as the boolean array used for filtering.

# %%
complaints[complaints['Complaint Type'] == 'Noise - Street/Sidewalk' ]

# %% [markdown]
# You can also combine more than one condition with the `&` operator like this:

# %%
is_noise = complaints['Complaint Type'] == "Noise - Street/Sidewalk"
in_brooklyn = complaints['Borough'] == "BROOKLYN"
# now, both must be true since we use & here:
complaints[~(is_noise & in_brooklyn)].iloc[:10,:]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
# 5    26592370  10/31/2013 01:46:52 AM                     NaN   NYPD
# 6    26595682  10/31/2013 01:46:40 AM                     NaN   NYPD
# 7    26595195  10/31/2013 01:44:19 AM  10/31/2013 01:58:49 AM   NYPD
# 8    26590540  10/31/2013 01:44:14 AM  10/31/2013 02:28:04 AM   NYPD
# 9    26594392  10/31/2013 01:34:41 AM  10/31/2013 02:23:51 AM   NYPD
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
# 5          New York City Police Department       Noise - Commercial
# 6          New York City Police Department         Blocked Driveway
# 7          New York City Police Department       Noise - Commercial
# 8          New York City Police Department       Noise - Commercial
# 9          New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
# 3                Car/Truck Horn      Street/Sidewalk        10023
# 4  Condition Attracting Rodents           Vacant Lot        10027
# 5              Banging/Pounding  Club/Bar/Restaurant        11372
# 6                     No Access      Street/Sidewalk        11419
# 7              Loud Music/Party  Club/Bar/Restaurant        11417
# 8                  Loud Talking  Club/Bar/Restaurant        10011
# 9              Loud Music/Party  Club/Bar/Restaurant        11225
#
#             Incident Address                    ...                     \
# 0           90-03 169 STREET                    ...
# 1                  58 AVENUE                    ...
# 2              4060 BROADWAY                    ...
# 3             WEST 72 STREET                    ...
# 4            WEST 124 STREET                    ...
# 5                  37 AVENUE                    ...
# 6          107-50 109 STREET                    ...
# 7  137-09 CROSSBAY BOULEVARD                    ...
# 8         258 WEST 15 STREET                    ...
# 9        835 NOSTRAND AVENUE                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
# 5                 NaN                      NaN       NaN
# 6                 NaN                      NaN       NaN
# 7                 NaN                      NaN       NaN
# 8                 NaN                      NaN       NaN
# 9                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
# 5                    NaN             NaN             NaN                 NaN
# 6                    NaN             NaN             NaN                 NaN
# 7                    NaN             NaN             NaN                 NaN
# 8                    NaN             NaN             NaN                 NaN
# 9                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
# 3  40.778009 -73.980213    (40.7780087446372, -73.98021349023975)
# 4  40.807691 -73.947387   (40.80769092704951, -73.94738703491433)
# 5  40.749989 -73.881988    (40.7499893014072, -73.88198770727831)
# 6  40.681533 -73.831737   (40.68153278675525, -73.83173699701601)
# 7  40.671816 -73.843092   (40.67181584567338, -73.84309181950769)
# 8  40.739913 -74.000790   (40.73991339303542, -74.00079028612932)
# 9  40.668204 -73.950648   (40.66820406598287, -73.95064760056546)
#
# [10 rows x 52 columns]

# %% [markdown]
# Or, to limit the columns we return -- we can specify them:

# %%
complaints[is_noise & in_brooklyn][['Complaint Type', 'Borough', 'Created Date', 'Descriptor']].index
# Out:
# Int64Index([    31,     49,    109,    236,    370,    378,    656,   1251,
#               5416,   5584,
#             ...
#             110937, 110939, 110941, 110946, 110960, 111002, 111006, 111021,
#             111035, 111054],
#            dtype='int64', length=456)

# %% [markdown]
# ## 4. Get information about data
# ### 4.1. Display the index, columns, and the underlying numpy data

# %%
complaints.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
# 3                Car/Truck Horn      Street/Sidewalk        10023
# 4  Condition Attracting Rodents           Vacant Lot        10027
#
#    Incident Address                    ...                     \
# 0  90-03 169 STREET                    ...
# 1         58 AVENUE                    ...
# 2     4060 BROADWAY                    ...
# 3    WEST 72 STREET                    ...
# 4   WEST 124 STREET                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
# 3  40.778009 -73.980213    (40.7780087446372, -73.98021349023975)
# 4  40.807691 -73.947387   (40.80769092704951, -73.94738703491433)
#
# [5 rows x 52 columns]

# %%
complaints.index
# Out:
# RangeIndex(start=0, stop=111069, step=1)

# %%
complaints.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'School Name', 'School Number',
#        'School Region', 'School Code', 'School Phone Number', 'School Address',
#        'School City', 'School State', 'School Zip', 'School Not Found',
#        'School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough',
#        'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Garage Lot Name', 'Ferry Direction', 'Ferry Terminal Name', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
complaints.values
# Out:
# 111069

# %%
complaints.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                       object
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Action Updated Date     object
# Community Board                    object
# Borough                            object
# X Coordinate (State Plane)        float64
# Y Coordinate (State Plane)        float64
# Park Facility Name                 object
# Park Borough                       object
# School Name                        object
# School Number                      object
# School Region                      object
# School Code                        object
# School Phone Number                object
# School Address                     object
# School City                        object
# School State                       object
# School Zip                         object
# School Not Found                   object
# School or Citywide Complaint      float64
# Vehicle Type                       object
# Taxi Company Borough               object
# Taxi Pick Up Location              object
# Bridge Highway Name                object
# Bridge Highway Direction           object
# Road Ramp                          object
# Bridge Highway Segment             object
# Garage Lot Name                    object
# Ferry Direction                    object
# Ferry Terminal Name                object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# dtype: object

# %% [markdown]
# ### 4.2. Describe data

# %%
bikes.describe()
# Only the numeric columns
# Out:
#            Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# count   310.000000                                0.0             310.000000
# mean   2985.048387                                NaN            1233.351613
# std    2169.271062                                NaN             944.643188
# min      32.000000                                NaN               0.000000
# 25%     596.000000                                NaN             243.250000
# 50%    3128.000000                                NaN            1269.000000
# 75%    4973.250000                                NaN            2003.000000
# max    7077.000000                                NaN            3124.000000
#
#        Maisonneuve 1  Maisonneuve 2      du Parc  Pierre-Dupuy      Rachel1  \
# count     310.000000     310.000000   310.000000    310.000000   310.000000
# mean     1983.325806    3510.261290  1862.983871   1054.306452  2873.483871
# std      1450.715170    2484.959789  1332.543266   1064.029205  2039.315504
# min        33.000000      47.000000    18.000000      0.000000     0.000000
# 25%       427.000000     831.000000   474.750000     53.250000   731.000000
# 50%      2019.500000    3688.500000  1822.500000    704.000000  3223.500000
# 75%      3168.250000    5731.750000  3069.000000   1818.500000  4717.250000
# max      4999.000000    8222.000000  4510.000000   4386.000000  6595.000000
#
#        St-Urbain (données non disponibles)
# count                                  0.0
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN

# %% [markdown]
# *Now we can see the min and max, and check if we were right!*

# %%
# We define a new function get_highest for DataFrame
def get_highest(data, name_column):
    highest = 0
    for value in data.loc[:,name_column]:
        if float(value) > highest:
            highest = float(value)
    return highest

# %%
get_highest(bikes, 'Maisonneuve 1')
# Out:
# 4999.0

# %% [markdown]
# #### Plotting histograms

# %%
bikes.hist(figsize = (20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EFA2893DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EFC2C09518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBE28DD68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBE2E7668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBF015358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBF015390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBF0E2A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBF0248D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001EFBF11F1D0>]], dtype=object)

# %%
# histogram of a specific column
bikes['Maisonneuve 1'].hist()

# %% [markdown]
# ### 4.3. Simple stats on Numerical columns

# %%
bikes['Côte-Sainte-Catherine'].sum()
# Out:
# 382339

# %%
bikes['Côte-Sainte-Catherine'].mean()
# Out:
# 1233.3516129032257

# %%
bikes['Côte-Sainte-Catherine'].max()
# Out:
# 3124

# %%
bikes['Côte-Sainte-Catherine'].min()
# Out:
# 0

# %%
bikes['Côte-Sainte-Catherine'].median()
# Out:
# 1269.0

# %% [markdown]
# ## 5. Reorganizing data
# ### 5.1. Transposing data

# %%
bikes.T
# Out:
#                                                      0                    1    \
# Date                                 2012-01-01 00:00:00  2012-01-02 00:00:00
# Berri 1                                               35                   83
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                  0                    1
# Maisonneuve 1                                         38                   68
# Maisonneuve 2                                         51                  153
# du Parc                                               26                   53
# Pierre-Dupuy                                          10                    6
# Rachel1                                               16                   43
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      2                    3    \
# Date                                 2012-01-03 00:00:00  2012-01-04 00:00:00
# Berri 1                                              135                  144
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                  2                    1
# Maisonneuve 1                                        104                  116
# Maisonneuve 2                                        248                  318
# du Parc                                               89                  111
# Pierre-Dupuy                                           3                    8
# Rachel1                                               58                   61
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      4                    5    \
# Date                                 2012-01-05 00:00:00  2012-01-06 00:00:00
# Berri 1                                              197                  146
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                  2                    0
# Maisonneuve 1                                        124                   98
# Maisonneuve 2                                        330                  244
# du Parc                                               97                   86
# Pierre-Dupuy                                          13                    4
# Rachel1                                               95                   75
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      6                    7    \
# Date                                 2012-01-07 00:00:00  2012-01-08 00:00:00
# Berri 1                                               98                   95
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                  2                    1
# Maisonneuve 1                                         80                   62
# Maisonneuve 2                                        108                   98
# du Parc                                               53                   64
# Pierre-Dupuy                                           6                   11
# Rachel1                                               54                   63
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      8                    9    \
# Date                                 2012-01-09 00:00:00  2012-01-10 00:00:00
# Berri 1                                              244                  397
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                  2                    3
# Maisonneuve 1                                        165                  238
# Maisonneuve 2                                        432                  563
# du Parc                                              198                  275
# Pierre-Dupuy                                          12                   18
# Rachel1                                              173                  241
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                             ...                           300  \
# Date                                        ...           2012-10-27 00:00:00
# Berri 1                                     ...                          1857
# Brébeuf (données non disponibles)           ...                           NaN
# Côte-Sainte-Catherine                       ...                           792
# Maisonneuve 1                               ...                          1244
# Maisonneuve 2                               ...                          2461
# du Parc                                     ...                          1193
# Pierre-Dupuy                                ...                           618
# Rachel1                                     ...                          2471
# St-Urbain (données non disponibles)         ...                           NaN
#
#                                                      301                  302  \
# Date                                 2012-10-28 00:00:00  2012-10-29 00:00:00
# Berri 1                                             1310                 2919
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                697                 1458
# Maisonneuve 1                                        910                 2071
# Maisonneuve 2                                       1776                 3768
# du Parc                                              955                 2440
# Pierre-Dupuy                                         387                  411
# Rachel1                                             1876                 2795
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      303                  304  \
# Date                                 2012-10-30 00:00:00  2012-10-31 00:00:00
# Berri 1                                             2887                 2634
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                               1251                 1294
# Maisonneuve 1                                       2007                 1835
# Maisonneuve 2                                       3516                 3453
# du Parc                                             2255                 2220
# Pierre-Dupuy                                         338                  245
# Rachel1                                             2790                 2570
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      305                  306  \
# Date                                 2012-11-01 00:00:00  2012-11-02 00:00:00
# Berri 1                                             2405                 1582
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                               1208                  737
# Maisonneuve 1                                       1701                 1109
# Maisonneuve 2                                       3082                 2277
# du Parc                                             2076                 1392
# Pierre-Dupuy                                         165                   97
# Rachel1                                             2461                 1888
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      307                  308  \
# Date                                 2012-11-03 00:00:00  2012-11-04 00:00:00
# Berri 1                                              844                  966
# Brébeuf (données non disponibles)                    NaN                  NaN
# Côte-Sainte-Catherine                                380                  446
# Maisonneuve 1                                        612                  710
# Maisonneuve 2                                       1137                 1277
# du Parc                                              713                  692
# Pierre-Dupuy                                         105                  197
# Rachel1                                             1302                 1374
# St-Urbain (données non disponibles)                  NaN                  NaN
#
#                                                      309
# Date                                 2012-11-05 00:00:00
# Berri 1                                             2247
# Brébeuf (données non disponibles)                    NaN
# Côte-Sainte-Catherine                               1170
# Maisonneuve 1                                       1705
# Maisonneuve 2                                       3221
# du Parc                                             2143
# Pierre-Dupuy                                         179
# Rachel1                                             2430
# St-Urbain (données non disponibles)                  NaN
#
# [10 rows x 310 columns]

# %% [markdown]
# ### 5.2. Sorting data

# %%
bikes.sort_values(by = 'Berri 1', ascending=False).head()
# add arg inplace = True to perform operation in-place
# Out:
#           Date  Berri 1  Brébeuf (données non disponibles)  \
# 166 2012-06-15     7077                                NaN
# 165 2012-06-14     6908                                NaN
# 184 2012-07-03     6712                                NaN
# 186 2012-07-05     6672                                NaN
# 234 2012-08-22     6529                                NaN
#
#      Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  \
# 166                   2469           4999           7663     4053
# 165                   2978           4809           7934     4223
# 184                   2634           4398           7416     3896
# 186                   2603           4830           7764     3816
# 234                   2671           4513           7065     3774
#
#      Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)
# 166          2293     6491                                  NaN
# 165          2386     6243                                  NaN
# 184          2606     5462                                  NaN
# 186          2746     5153                                  NaN
# 234          2391     5154                                  NaN

# %%
# it's possible to sort a column with the same function
bikes['du Parc'].sort_values().head()
# Out:
# 55    18
# 14    18
# 13    19
# 0     26
# 20    32
# Name: du Parc, dtype: int64

# %% [markdown]
# ## 6. Transforming data
# ### 6.1. Transforming existing data
# *To avoid transforming df, we first make a copy*

# %%
complaints_copy = complaints.copy()
# df_copy = df only creates a alias, not a new object !
bikes_copy = bikes.copy()

# %% [markdown]
# *You just have to assign new values to a selection *

# %%
complaints_copy.loc[0:2,'Unique Key'] = np.array([1,2,3])
complaints_copy.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0           1  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1           2  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2           3  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
# 3                Car/Truck Horn      Street/Sidewalk        10023
# 4  Condition Attracting Rodents           Vacant Lot        10027
#
#    Incident Address                    ...                     \
# 0  90-03 169 STREET                    ...
# 1         58 AVENUE                    ...
# 2     4060 BROADWAY                    ...
# 3    WEST 72 STREET                    ...
# 4   WEST 124 STREET                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
# 3  40.778009 -73.980213    (40.7780087446372, -73.98021349023975)
# 4  40.807691 -73.947387   (40.80769092704951, -73.94738703491433)
#
# [5 rows x 52 columns]

# %% [markdown]
# ### 6.2. Adding new data

# %%
# Adding a column
bikes_copy['Daily Total'] = bikes['Berri 1'] + bikes['Côte-Sainte-Catherine'] + bikes['Maisonneuve 1'] + bikes['Maisonneuve 2']+ bikes['du Parc']+ bikes['Pierre-Dupuy']+ bikes['Rachel1']
bikes_copy.head()
# Out:
#         Date  Berri 1  Brébeuf (données non disponibles)  \
# 0 2012-01-01       35                                NaN
# 1 2012-01-02       83                                NaN
# 2 2012-01-03      135                                NaN
# 3 2012-01-04      144                                NaN
# 4 2012-01-05      197                                NaN
#
#    Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  \
# 0                      0             38             51       26            10
# 1                      1             68            153       53             6
# 2                      2            104            248       89             3
# 3                      1            116            318      111             8
# 4                      2            124            330       97            13
#
#    Rachel1  St-Urbain (données non disponibles)  Daily Total
# 0       16                                  NaN          176
# 1       43                                  NaN          407
# 2       58                                  NaN          639
# 3       61                                  NaN          759
# 4       95                                  NaN          858

# %% [markdown]
# ### 6.3. Dropping data

# %%
# put axis = 1 to drop a column
bikes_copy.drop('Brébeuf (données non disponibles)', axis = 1, inplace = True)
bikes_copy.head()
# Out:
#         Date  Berri 1  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  \
# 0 2012-01-01       35                      0             38             51
# 1 2012-01-02       83                      1             68            153
# 2 2012-01-03      135                      2            104            248
# 3 2012-01-04      144                      1            116            318
# 4 2012-01-05      197                      2            124            330
#
#    du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)  \
# 0       26            10       16                                  NaN
# 1       53             6       43                                  NaN
# 2       89             3       58                                  NaN
# 3      111             8       61                                  NaN
# 4       97            13       95                                  NaN
#
#    Daily Total
# 0          176
# 1          407
# 2          639
# 3          759
# 4          858

# %% [markdown]
# ### 6.3. Reseting Index

# %%
bikes_copy = bikes_copy.sort_values(by = 'Daily Total',ascending=False)
bikes_copy.head()
# Out:
#    index       Date  Berri 1  Côte-Sainte-Catherine  Maisonneuve 1  \
# 0      0 2012-06-14     6908                   2978           4809
# 1      1 2012-06-15     7077                   2469           4999
# 2      2 2012-09-13     6520                   3076           4369
# 3      3 2012-07-05     6672                   2603           4830
# 4      4 2012-09-12     6349                   3124           4209
#
#    Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# 0           7934     4223          2386     6243
# 1           7663     4053          2293     6491
# 2           7514     4494          1986     5742
# 3           7764     3816          2746     5153
# 4           7292     4510          1981     5697
#
#    St-Urbain (données non disponibles)  Daily Total
# 0                                  NaN        35481
# 1                                  NaN        35045
# 2                                  NaN        33701
# 3                                  NaN        33584
# 4                                  NaN        33162

# %%
bikes_copy.reset_index(inplace=True, drop = True)
bikes_copy.head()
# drop = True means not to keep the old index
# Out:
#    index       Date  Berri 1  Côte-Sainte-Catherine  Maisonneuve 1  \
# 0      0 2012-06-14     6908                   2978           4809
# 1      1 2012-06-15     7077                   2469           4999
# 2      2 2012-09-13     6520                   3076           4369
# 3      3 2012-07-05     6672                   2603           4830
# 4      4 2012-09-12     6349                   3124           4209
#
#    Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# 0           7934     4223          2386     6243
# 1           7663     4053          2293     6491
# 2           7514     4494          1986     5742
# 3           7764     3816          2746     5153
# 4           7292     4510          1981     5697
#
#    St-Urbain (données non disponibles)  Daily Total
# 0                                  NaN        35481
# 1                                  NaN        35045
# 2                                  NaN        33701
# 3                                  NaN        33584
# 4                                  NaN        33162

# %% [markdown]
# ### 6.4. Applying a Function to Each Column

# %%
proportions = bikes_copy.iloc[:,2:].apply(lambda x: x/x['Daily Total'], axis=1)
proportions.head()
# Out:
#     Berri 1  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2   du Parc  \
# 0  0.194696               0.083932       0.135537       0.223613  0.119021
# 1  0.201940               0.070452       0.142645       0.218662  0.115651
# 2  0.193466               0.091273       0.129640       0.222961  0.133349
# 3  0.198666               0.077507       0.143818       0.231182  0.113626
# 4  0.191454               0.094204       0.126922       0.219890  0.135999
#
#    Pierre-Dupuy   Rachel1  St-Urbain (données non disponibles)  Daily Total
# 0      0.067247  0.175953                                  NaN          1.0
# 1      0.065430  0.185219                                  NaN          1.0
# 2      0.058930  0.170381                                  NaN          1.0
# 3      0.081765  0.153436                                  NaN          1.0
# 4      0.059737  0.171793                                  NaN          1.0

# %% [markdown]
# ### 6.4. Dealing with NA

# %%
# To get the boolean mask where values are NaN 
bikes_copy.isnull().head()
# Out:
#    index   Date  Berri 1  Côte-Sainte-Catherine  Maisonneuve 1  Maisonneuve 2  \
# 0  False  False    False                  False          False          False
# 1  False  False    False                  False          False          False
# 2  False  False    False                  False          False          False
# 3  False  False    False                  False          False          False
# 4  False  False    False                  False          False          False
#
#    du Parc  Pierre-Dupuy  Rachel1  St-Urbain (données non disponibles)  \
# 0    False         False    False                                 True
# 1    False         False    False                                 True
# 2    False         False    False                                 True
# 3    False         False    False                                 True
# 4    False         False    False                                 True
#
#    Daily Total
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
# Filling missing data
bikes_copy.fillna(value = 0, inplace=False).head()
# Out:
#    index       Date  Berri 1  Côte-Sainte-Catherine  Maisonneuve 1  \
# 0      0 2012-06-14     6908                   2978           4809
# 1      1 2012-06-15     7077                   2469           4999
# 2      2 2012-09-13     6520                   3076           4369
# 3      3 2012-07-05     6672                   2603           4830
# 4      4 2012-09-12     6349                   3124           4209
#
#    Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# 0           7934     4223          2386     6243
# 1           7663     4053          2293     6491
# 2           7514     4494          1986     5742
# 3           7764     3816          2746     5153
# 4           7292     4510          1981     5697
#
#    St-Urbain (données non disponibles)  Daily Total
# 0                                  0.0        35481
# 1                                  0.0        35045
# 2                                  0.0        33701
# 3                                  0.0        33584
# 4                                  0.0        33162

# %%
# the value can be a string 
# It's also a function for a serie 
complaints.head(3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department          Illegal Parking
# 2  New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
#
#    Incident Address                    ...                     \
# 0  90-03 169 STREET                    ...
# 1         58 AVENUE                    ...
# 2     4060 BROADWAY                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
#
# [3 rows x 52 columns]

# %%
complaints_copy['Closed Date'].fillna(value='Unknown', inplace= True)
complaints_copy.head(3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0           1  10/31/2013 02:08:41 AM                 Unknown   NYPD
# 1           2  10/31/2013 02:01:04 AM                 Unknown   NYPD
# 2           3  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department          Illegal Parking
# 2  New York City Police Department       Noise - Commercial
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
#
#    Incident Address                    ...                     \
# 0  90-03 169 STREET                    ...
# 1         58 AVENUE                    ...
# 2     4060 BROADWAY                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
#
# [3 rows x 52 columns]

# %%
# Dropping NaN
complaints.dropna(axis = 0, how = 'all', inplace = False).head()
# axis where missing values are dropped, 0 <=> row and 1 <=> column
# how : if 'any' NaN are present, drop that label 
#       if 'all' labels are NA, drop that label
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk        11432
# 1  Commercial Overnight Parking      Street/Sidewalk        11378
# 2              Loud Music/Party  Club/Bar/Restaurant        10032
# 3                Car/Truck Horn      Street/Sidewalk        10023
# 4  Condition Attracting Rodents           Vacant Lot        10027
#
#    Incident Address                    ...                     \
# 0  90-03 169 STREET                    ...
# 1         58 AVENUE                    ...
# 2     4060 BROADWAY                    ...
# 3    WEST 72 STREET                    ...
# 4   WEST 124 STREET                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.708275 -73.791604   (40.70827532593202, -73.79160395779721)
# 1  40.721041 -73.909453  (40.721040535628305, -73.90945306791765)
# 2  40.843330 -73.939144   (40.84332975466513, -73.93914371913482)
# 3  40.778009 -73.980213    (40.7780087446372, -73.98021349023975)
# 4  40.807691 -73.947387   (40.80769092704951, -73.94738703491433)
#
# [5 rows x 52 columns]

# %% [markdown]
# ## 7. Counting Values And Filtering<a name="_counting values and filtering"></a>
#
# What's the most common complaint type? This is a really easy question to answer! There's a `.value_counts()` method that we can use:

# %%
complaints['Complaint Type'].value_counts()
# Out:
# HEATING                                 14200
# GENERAL CONSTRUCTION                     7471
# Street Light Condition                   7117
# DOF Literature Request                   5797
# PLUMBING                                 5373
# PAINT - PLASTER                          5149
# Blocked Driveway                         4590
# NONCONST                                 3998
# Street Condition                         3473
# Illegal Parking                          3343
# Noise                                    3321
# Traffic Signal Condition                 3145
# Dirty Conditions                         2653
# Water System                             2636
# Noise - Commercial                       2578
# ELECTRIC                                 2350
# Broken Muni Meter                        2070
# Noise - Street/Sidewalk                  1928
# Sanitation Condition                     1824
# Rodent                                   1632
# Sewer                                    1627
# Consumer Complaint                       1227
# Taxi Complaint                           1227
# Damaged Tree                             1180
# Overgrown Tree/Branches                  1083
# Graffiti                                  973
# Missed Collection (All Materials)         973
# Building/Use                              942
# Root/Sewer/Sidewalk Condition             836
# Derelict Vehicle                          803
#                                         ...
# Poison Ivy                                  5
# Fire Alarm - Modification                   5
# Internal Code                               5
# Posting Advertisement                       5
# Miscellaneous Categories                    5
# Transportation Provider Complaint           4
# Special Natural Area District (SNAD)        4
# Illegal Animal Sold                         4
# Ferry Complaint                             4
# Invitation                                  3
# Fire Alarm - Replacement                    3
# Illegal Fireworks                           3
# Adopt-A-Basket                              3
# Opinion for the Mayor                       2
# Legal Services Provider Complaint           2
# Public Assembly                             2
# Misc. Comments                              2
# DFTA Literature Request                     2
# Window Guard                                2
# DHS Income Savings Requirement              1
# Ferry Permit                                1
# Snow                                        1
# Municipal Parking Facility                  1
# Stalled Sites                               1
# X-Ray Machine/Equipment                     1
# Highway Sign - Damaged                      1
# DWD                                         1
# Trans Fat                                   1
# Tunnel Condition                            1
# Open Flame Permit                           1
# Name: Complaint Type, Length: 165, dtype: int64

# %% [markdown]
# If we just wanted the top 10 most common complaints, we can do this:

# %%
complaint_counts = complaints['Complaint Type'].value_counts()
complaint_counts[:10]
# Out:
# HEATING                   14200
# GENERAL CONSTRUCTION       7471
# Street Light Condition     7117
# DOF Literature Request     5797
# PLUMBING                   5373
# PAINT - PLASTER            5149
# Blocked Driveway           4590
# NONCONST                   3998
# Street Condition           3473
# Illegal Parking            3343
# Name: Complaint Type, dtype: int64

# %%
dict(complaint_counts)
# Out:
# {'APPLIANCE': 445,
#  'Adopt-A-Basket': 3,
#  'Agency Issues': 174,
#  'Air Quality': 459,
#  'Animal Abuse': 164,
#  'Animal Facility - No Permit': 8,
#  'Animal in a Park': 84,
#  'Asbestos': 143,
#  'BEST/Site Safety': 52,
#  'Beach/Pool/Sauna Complaint': 7,
#  'Benefit Card Replacement': 387,
#  'Bike Rack Condition': 7,
#  'Bike/Roller/Skate Chronic': 32,
#  'Blocked Driveway': 4590,
#  'Boilers': 86,
#  'Bridge Condition': 20,
#  'Broken Muni Meter': 2070,
#  'Building/Use': 942,
#  'Bus Stop Shelter Placement': 14,
#  'CONSTRUCTION': 65,
#  'City Vehicle Placard Complaint': 32,
#  'Collection Truck Noise': 8,
#  'Complaint': 9,
#  'Compliment': 9,
#  'Construction': 420,
#  'Consumer Complaint': 1227,
#  'Cranes and Derricks': 10,
#  'Curb Condition': 66,
#  'DCA / DOH New License Application Request': 164,
#  'DCA Literature Request': 14,
#  'DFTA Literature Request': 2,
#  'DHS Income Savings Requirement': 1,
#  'DOF Literature Request': 5797,
#  'DOF Parking - Tax Exemption': 43,
#  'DOT Literature Request': 123,
#  'DPR Internal': 86,
#  'DPR Literature Request': 7,
#  'DWD': 1,
#  'Damaged Tree': 1180,
#  'Dead Tree': 630,
#  'Derelict Bicycle': 83,
#  'Derelict Vehicle': 803,
#  'Derelict Vehicles': 801,
#  'Dirty Conditions': 2653,
#  'Disorderly Youth': 26,
#  'Drinking': 83,
#  'Drinking Water': 11,
#  'EAP Inspection - F59': 126,
#  'ELECTRIC': 2350,
#  'Electrical': 86,
#  'Elevator': 244,
#  'Ferry Complaint': 4,
#  'Ferry Inquiry': 32,
#  'Ferry Permit': 1,
#  'Fire Alarm - Modification': 5,
#  'Fire Alarm - New System': 6,
#  'Fire Alarm - Reinspection': 18,
#  'Fire Alarm - Replacement': 3,
#  'Fire Safety Director - F58': 441,
#  'Food Establishment': 485,
#  'Food Poisoning': 152,
#  'For Hire Vehicle Complaint': 173,
#  'Found Property': 18,
#  'GENERAL CONSTRUCTION': 7471,
#  'General Construction/Plumbing': 738,
#  'Graffiti': 973,
#  'HEATING': 14200,
#  'Harboring Bees/Wasps': 14,
#  'Hazardous Materials': 171,
#  'Highway Condition': 130,
#  'Highway Sign - Damaged': 1,
#  'Homeless Encampment': 269,
#  'Homeless Person Assistance': 99,
#  'Illegal Animal Kept as Pet': 21,
#  'Illegal Animal Sold': 4,
#  'Illegal Fireworks': 3,
#  'Illegal Parking': 3343,
#  'Illegal Tree Damage': 163,
#  'Indoor Air Quality': 254,
#  'Indoor Sewage': 104,
#  'Industrial Waste': 145,
#  'Internal Code': 5,
#  'Investigations and Discipline (IAD)': 40,
#  'Invitation': 3,
#  'Lead': 167,
#  'Legal Services Provider Complaint': 2,
#  'Litter Basket / Request': 252,
#  'Maintenance or Facility': 455,
#  'Misc. Comments': 2,
#  'Miscellaneous Categories': 5,
#  'Missed Collection (All Materials)': 973,
#  'Mold': 26,
#  'Municipal Parking Facility': 1,
#  'NONCONST': 3998,
#  'Noise': 3321,
#  'Noise - Commercial': 2578,
#  'Noise - Helicopter': 99,
#  'Noise - House of Worship': 67,
#  'Noise - Park': 191,
#  'Noise - Street/Sidewalk': 1928,
#  'Noise - Vehicle': 750,
#  'Non-Residential Heat': 106,
#  'OEM Literature Request': 29,
#  'Open Flame Permit': 1,
#  'Opinion for the Mayor': 2,
#  'Other Enforcement': 358,
#  'Overflowing Litter Baskets': 96,
#  'Overgrown Tree/Branches': 1083,
#  'PAINT - PLASTER': 5149,
#  'PLUMBING': 5373,
#  'Panhandling': 23,
#  'Parking Card': 8,
#  'Plant': 34,
#  'Plumbing': 66,
#  'Poison Ivy': 5,
#  'Posting Advertisement': 5,
#  'Public Assembly': 2,
#  'Public Payphone Complaint': 31,
#  'Public Toilet': 6,
#  'Recycling Enforcement': 56,
#  'Request for Information': 18,
#  'Rodent': 1632,
#  'Root/Sewer/Sidewalk Condition': 836,
#  'SCRIE': 530,
#  'STRUCTURAL': 16,
#  'Sanitation Condition': 1824,
#  'Scaffold Safety': 8,
#  'School Maintenance': 97,
#  'Senior Center Complaint': 14,
#  'Sewer': 1627,
#  'Sidewalk Condition': 339,
#  'Smoking': 113,
#  'Snow': 1,
#  'Special Enforcement': 206,
#  'Special Natural Area District (SNAD)': 4,
#  'Special Projects Inspection Team (SPIT)': 106,
#  'Stalled Sites': 1,
#  'Standing Water': 64,
#  'Street Condition': 3473,
#  'Street Light Condition': 7117,
#  'Street Sign - Damaged': 691,
#  'Street Sign - Dangling': 110,
#  'Street Sign - Missing': 327,
#  'Sweeping/Missed-Inadequate': 164,
#  'Tattooing': 6,
#  'Taxi Complaint': 1227,
#  'Taxi Compliment': 73,
#  'Traffic': 168,
#  'Traffic Signal Condition': 3145,
#  'Trans Fat': 1,
#  'Transportation Provider Complaint': 4,
#  'Tunnel Condition': 1,
#  'Unleashed Dog': 36,
#  'Unsanitary Animal Facility': 6,
#  'Unsanitary Animal Pvt Property': 106,
#  'Unsanitary Pigeon Condition': 41,
#  'Urinating in Public': 30,
#  'Vacant Lot': 146,
#  'Vending': 229,
#  'Violation of Park Rules': 90,
#  'Water Conservation': 130,
#  'Water Quality': 89,
#  'Water System': 2636,
#  'Window Guard': 2,
#  'X-Ray Machine/Equipment': 1}

# %% [markdown]
# But it gets better! We can plot them!

# %%
complaint_counts[:10].plot(kind='bar')

# %% [markdown]
# We can also see how many unique types of complaints there are in the column, using `.unique` and len (for length):

# %%
complaints['Agency'].unique()
# Out:
# array(['NYPD', 'DOHMH', 'DOT', 'TLC', 'HRA', 'DSNY', 'HPD', 'DCA', 'DEP',
#        'EDC', 'DHS', 'DPR', 'DOF', 'CHALL', 'DOE', 'DOB', 'FDNY', 'DOITT',
#        '3-1-1', 'DFTA', 'COIB', 'OEM', 'OATH', 'OPS', 'OMB', 'DOP'], dtype=object)

# %%
# get the number of unique values for a feature
len(complaints['Agency'].unique())
# Out:
# 26

# %% [markdown]
# ## 8. Application : Which Borough has the Most Noise Complaints?<a name="_ 8. application : which borough has the most noise complaints?"></a>

# %% [markdown]
# To get the noise complaints, we first need to find the rows where the "Complaint Type" column is "Noise - Street/Sidewalk". We use boolean indexing (3.2.)

# %%
noise_complaints = complaints[  complaints['Complaint Type'] == "Noise - Street/Sidewalk"  ] 
noise_complaints[0:10]
# Out:
#      Unique Key            Created Date             Closed Date Agency  \
# 0      26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 16     26594086  10/31/2013 12:54:03 AM  10/31/2013 02:16:39 AM   NYPD
# 25     26591573  10/31/2013 12:35:18 AM  10/31/2013 02:41:35 AM   NYPD
# 28     26594085  10/31/2013 12:32:08 AM                     NaN   NYPD
# 31     26595564  10/31/2013 12:30:36 AM                     NaN   NYPD
# 45     26590446  10/31/2013 12:11:58 AM  10/31/2013 01:54:38 AM   NYPD
# 49     26595553  10/31/2013 12:05:10 AM  10/31/2013 02:43:43 AM   NYPD
# 87     26590695  10/30/2013 11:40:52 PM                     NaN   NYPD
# 109    26594653  10/30/2013 11:26:32 PM  10/31/2013 12:18:54 AM   NYPD
# 122    26594760  10/30/2013 11:17:43 PM  10/31/2013 01:05:43 AM   NYPD
#
#                          Agency Name           Complaint Type  \
# 0    New York City Police Department  Noise - Street/Sidewalk
# 16   New York City Police Department  Noise - Street/Sidewalk
# 25   New York City Police Department  Noise - Street/Sidewalk
# 28   New York City Police Department  Noise - Street/Sidewalk
# 31   New York City Police Department  Noise - Street/Sidewalk
# 45   New York City Police Department  Noise - Street/Sidewalk
# 49   New York City Police Department  Noise - Street/Sidewalk
# 87   New York City Police Department  Noise - Street/Sidewalk
# 109  New York City Police Department  Noise - Street/Sidewalk
# 122  New York City Police Department  Noise - Street/Sidewalk
#
#            Descriptor    Location Type Incident Zip     Incident Address  \
# 0        Loud Talking  Street/Sidewalk        11432     90-03 169 STREET
# 16   Loud Music/Party  Street/Sidewalk        10310  173 CAMPBELL AVENUE
# 25       Loud Talking  Street/Sidewalk        10312    24 PRINCETON LANE
# 28       Loud Talking  Street/Sidewalk        10026  121 WEST 116 STREET
# 31   Loud Music/Party  Street/Sidewalk        11236             AVENUE J
# 45   Loud Music/Party  Street/Sidewalk        10459  819 EAST 167 STREET
# 49       Loud Talking  Street/Sidewalk        11225   25 LEFFERTS AVENUE
# 87       Loud Talking  Street/Sidewalk        10027  449 WEST 125 STREET
# 109  Loud Music/Party  Street/Sidewalk        11222                  NaN
# 122  Loud Music/Party  Street/Sidewalk        10005       67 WALL STREET
#
#                        ...                    Bridge Highway Name  \
# 0                      ...                                    NaN
# 16                     ...                                    NaN
# 25                     ...                                    NaN
# 28                     ...                                    NaN
# 31                     ...                                    NaN
# 45                     ...                                    NaN
# 49                     ...                                    NaN
# 87                     ...                                    NaN
# 109                    ...                                    NaN
# 122                    ...                                    NaN
#
#     Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name  \
# 0                        NaN       NaN                    NaN             NaN
# 16                       NaN       NaN                    NaN             NaN
# 25                       NaN       NaN                    NaN             NaN
# 28                       NaN       NaN                    NaN             NaN
# 31                       NaN       NaN                    NaN             NaN
# 45                       NaN       NaN                    NaN             NaN
# 49                       NaN       NaN                    NaN             NaN
# 87                       NaN       NaN                    NaN             NaN
# 109                      NaN       NaN                    NaN             NaN
# 122                      NaN       NaN                    NaN             NaN
#
#     Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0               NaN                 NaN  40.708275 -73.791604
# 16              NaN                 NaN  40.636182 -74.116150
# 25              NaN                 NaN  40.553421 -74.196743
# 28              NaN                 NaN  40.802390 -73.950526
# 31              NaN                 NaN  40.634104 -73.911055
# 45              NaN                 NaN  40.826623 -73.899965
# 49              NaN                 NaN  40.661793 -73.959934
# 87              NaN                 NaN  40.812717 -73.955678
# 109             NaN                 NaN  40.724600 -73.954271
# 122             NaN                 NaN  40.705749 -74.008342
#
#                                      Location
# 0     (40.70827532593202, -73.79160395779721)
# 16     (40.63618202176914, -74.1161500428337)
# 25    (40.55342078716953, -74.19674315017886)
# 28    (40.80238950799943, -73.95052644123253)
# 31   (40.634103775951736, -73.91105541883589)
# 45    (40.826622810177874, -73.8999653556452)
# 49     (40.6617931276793, -73.95993363978067)
# 87    (40.81271725522785, -73.95567750031833)
# 109  (40.724599563793525, -73.95427134534344)
# 122   (40.70574909022401, -74.00834244292587)
#
# [10 rows x 52 columns]

# %%
noise_complaints['Borough'].value_counts().plot(kind = 'bar')

# %% [markdown]
# It's Manhattan! But what if we wanted to divide by the total number of complaints, to make it make a bit more sense? That would be easy too:

# %%
complaints['Borough'].value_counts()
# Out:
# BROOKLYN         32890
# MANHATTAN        24288
# QUEENS           22281
# BRONX            19686
# Unspecified       7107
# STATEN ISLAND     4817
# Name: Borough, dtype: int64

# %%
results = noise_complaints['Borough'].value_counts() / complaints['Borough'].value_counts()
results
# Out:
# BRONX            0.014833
# BROOKLYN         0.013864
# MANHATTAN        0.037755
# QUEENS           0.010143
# STATEN ISLAND    0.007474
# Unspecified      0.000141
# Name: Borough, dtype: float64

# %% [markdown]
# What if we want to graph this?
# The default is a line graph, which is not the right type for this kind of data.  This data is not timeseries (where the X axis is dates/times).  This data is count data by categories that are not ordered -- "boroughs."  The proper type of chart for this is a bar graph.

# %%
results.plot()

# %%
# we can use the keyword argument kind for this:
results.sort_values(ascending=False).plot(kind = 'bar')
